# %%
import numpy as np
from scipy import stats
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import data_cleaning as dc
import api

sns.set_style('whitegrid')

# %config InlineBackend.figure_format = 'retina'
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %%
df = dc.full_clean()

# %%
#Most and Least GreenSpace
df_green = df.sort_values(by=['greenspace'],ascending=False)
df_green['area'].iloc[0], df_green['area'].iloc[-1]
# Out:
# ('Havering', 'City of London')

# %%
#Highest and Lowest House Price
df_price = df.sort_values(by=['house_price'],ascending=False)
df_price['area'].iloc[0], df_price['area'].iloc[-1]
# Out:
# ('Kensington and Chelsea', 'Barking and Dagenham')

# %%
#Highest and Lowest Happiness
df_hap = df.sort_values(by=['happiness'],ascending=False)
df_hap['area'].iloc[0], df_price['area'].iloc[-1]
# Out:
# ('Kensington and Chelsea', 'Barking and Dagenham')

# %%
#Highest and Lowest Carbon Emmission
df_car = df.sort_values(by=['carbon_emmision'],ascending=False)
df_car['area'].iloc[0], df_price['area'].iloc[-1]
# Out:
# ('Westminster', 'Barking and Dagenham')

# %%
#Highest and Lowest House Population
df_pop = df.sort_values(by=['population'],ascending=False)
df_pop['area'].iloc[0], df_price['area'].iloc[-1]
# Out:
# ('Islington', 'Barking and Dagenham')

# %%
#Highest and Lowest Number of Cars
df_car = df.sort_values(by=['cars'],ascending=False)
df_car['area'].iloc[0], df_price['area'].iloc[-1]
# Out:
# ('Bromley', 'Barking and Dagenham')

# %%
#Grouping by political party
df_pol = df.sort_values(by=['political'])
df_pol[df_pol['political'] == 'Cons']
df_pol[df_pol['political'] == 'Lab']
# Out:
#          code                    area   inner_outer  population unemployment  \
# 10  E09000011               Greenwich  Outer London        58.8          8.1
# 30  E09000031          Waltham Forest  Outer London        71.1          5.4
# 27  E09000028               Southwark  Inner London       108.2          7.7
# 1   E09000002    Barking and Dagenham  Outer London        57.3           11
# 25  E09000026               Redbridge  Outer London        53.3          7.9
# 24  E09000025                  Newham  Inner London        93.5          9.1
# 23  E09000024                  Merton  Outer London        55.7          4.6
# 22  E09000023                Lewisham  Inner London        84.7          5.7
# 9   E09000010                 Enfield  Outer London        41.0          3.8
# 7   E09000008                 Croydon  Outer London        44.4          4.1
# 21  E09000022                 Lambeth  Inner London       121.4          5.9
# ...

# %%
#Grouping by Inner / Outer London
df_pol = df.sort_values(by=['inner_outer'])
df_pol[df_pol['inner_outer'] == 'Inner London']
df_pol[df_pol['inner_outer'] == 'Outer London']
# Out:
#          code                  area   inner_outer  population unemployment  \
# 10  E09000011             Greenwich  Outer London        58.8          8.1
# 30  E09000031        Waltham Forest  Outer London        71.1          5.4
# 1   E09000002  Barking and Dagenham  Outer London        57.3           11
# 28  E09000029                Sutton  Outer London        46.1          5.5
# 2   E09000003                Barnet  Outer London        44.5          8.5
# 26  E09000027  Richmond upon Thames  Outer London        34.3          3.8
# 25  E09000026             Redbridge  Outer London        53.3          7.9
# 3   E09000004                Bexley  Outer London        39.9          7.6
# 23  E09000024                Merton  Outer London        55.7          4.6
# 4   E09000005                 Brent  Outer London        76.1          7.5
# 20  E09000021  Kingston upon Thames  Outer London        46.3          4.5
# ...
